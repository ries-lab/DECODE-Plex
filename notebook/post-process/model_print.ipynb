# %%
import torch

from pathlib import Path

ckpt_path = Path("/home/shahao/projects/DECODE-Plex/outputs/Biplane/2026-05-14_18-41-52-743948/epoch=0-step=313.ckpt")

ckpt = torch.load(ckpt_path, map_location="cpu")

state_dict = ckpt["state_dict"]

print(len(state_dict))

print(list(state_dict.keys())[:100])
# Out:
# 100
# ['_model._models_shared.0.encoder.0.0.weight', '_model._models_shared.0.encoder.0.0.bias', '_model._models_shared.0.encoder.0.2.weight', '_model._models_shared.0.encoder.0.2.bias', '_model._models_shared.0.encoder.1.0.weight', '_model._models_shared.0.encoder.1.0.bias', '_model._models_shared.0.encoder.1.2.weight', '_model._models_shared.0.encoder.1.2.bias', '_model._models_shared.0.encoder.2.0.weight', '_model._models_shared.0.encoder.2.0.bias', '_model._models_shared.0.encoder.2.2.weight', '_model._models_shared.0.encoder.2.2.bias', '_model._models_shared.0.base.0.weight', '_model._models_shared.0.base.0.bias', '_model._models_shared.0.base.2.weight', '_model._models_shared.0.base.2.bias', '_model._models_shared.0.decoder.0.0.weight', '_model._models_shared.0.decoder.0.0.bias', '_model._models_shared.0.decoder.0.2.weight', '_model._models_shared.0.decoder.0.2.bias', '_model._models_shared.0.decoder.1.0.weight', '_model._models_shared.0.decoder.1.0.bias', '_model._models_shared.0.decoder.1.2.weight', '_model._models_shared.0.decoder.1.2.bias', '_model._models_shared.0.decoder.2.0.weight', '_model._models_shared.0.decoder.2.0.bias', '_model._models_shared.0.decoder.2.2.weight', '_model._models_shared.0.decoder.2.2.bias', '_model._models_shared.0.poolers.0.weight', '_model._models_shared.0.poolers.0.bias', '_model._models_shared.0.poolers.1.weight', '_model._models_shared.0.poolers.1.bias', '_model._models_shared.0.poolers.2.weight', '_model._models_shared.0.poolers.2.bias', '_model._models_shared.0.upsamplers.0.conv.weight', '_model._models_shared.0.upsamplers.0.conv.bias', '_model._models_shared.0.upsamplers.1.conv.weight', '_model._models_shared.0.upsamplers.1.conv.bias', '_model._models_shared.0.upsamplers.2.conv.weight', '_model._models_shared.0.upsamplers.2.conv.bias', '_model._models_shared.0.out_conv.weight', '_model._models_shared.0.out_conv.bias', '_model._model_union.encoder.0.0.weight', '_model._model_union.encoder.0.0.bias', '_model._model_union.encoder.0.2.weight', '_model._model_union.encoder.0.2.bias', '_model._model_union.encoder.1.0.weight', '_model._model_union.encoder.1.0.bias', '_model._model_union.encoder.1.2.weight', '_model._model_union.encoder.1.2.bias', '_model._model_union.encoder.2.0.weight', '_model._model_union.encoder.2.0.bias', '_model._model_union.encoder.2.2.weight', '_model._model_union.encoder.2.2.bias', '_model._model_union.base.0.weight', '_model._model_union.base.0.bias', '_model._model_union.base.2.weight', '_model._model_union.base.2.bias', '_model._model_union.decoder.0.0.weight', '_model._model_union.decoder.0.0.bias', '_model._model_union.decoder.0.2.weight', '_model._model_union.decoder.0.2.bias', '_model._model_union.decoder.1.0.weight', '_model._model_union.decoder.1.0.bias', '_model._model_union.decoder.1.2.weight', '_model._model_union.decoder.1.2.bias', '_model._model_union.decoder.2.0.weight', '_model._model_union.decoder.2.0.bias', '_model._model_union.decoder.2.2.weight', '_model._model_union.decoder.2.2.bias', '_model._model_union.poolers.0.weight', '_model._model_union.poolers.0.bias', '_model._model_union.poolers.1.weight', '_model._model_union.poolers.1.bias', '_model._model_union.poolers.2.weight', '_model._model_union.poolers.2.bias', '_model._model_union.upsamplers.0.conv.weight', '_model._model_union.upsamplers.0.conv.bias', '_model._model_union.upsamplers.1.conv.weight', '_model._model_union.upsamplers.1.conv.bias', '_model._model_union.upsamplers.2.conv.weight', '_model._model_union.upsamplers.2.conv.bias', '_model._model_union.out_conv.weight', '_model._model_union.out_conv.bias', '_model._model_heads.0.core.0.weight', '_model._model_heads.0.core.0.bias', '_model._model_heads.0.out_conv.weight', '_model._model_heads.0.out_conv.bias', '_model._model_heads.1.core.0.weight', '_model._model_heads.1.core.0.bias', '_model._model_heads.1.out_conv.weight', '_model._model_heads.1.out_conv.bias', '_model._model_heads.2.core.0.weight', '_model._model_heads.2.core.0.bias', '_m ...
